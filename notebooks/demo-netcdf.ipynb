# %% [markdown]
# ### Import the library

# %%
import bigdatavoyant as bdv

# %% [markdown]
# ### Load netCDF file

# %%
ds = bdv.io.read_file('data/local/test_echam_spectral-deflated.nc', type='netcdf', lat_attr='lat')

# %% [markdown]
# ### Metadata

# %%
ds.metadata()
# Out:
# {'CDI': 'Climate Data Interface version 1.4.6 (http://code.zmaw.de/projects/cdi)',
#  'Conventions': 'CF-1.0',
#  'source': 'ECHAM6.1',
#  'institution': 'Max-Planck-Institute for Meteorology',
#  'title': 'homo_chem_hammoz_20141128',
#  'echam_version': '6.1.00',
#  'advection': 'Lin & Rood',
#  'physics': 'Modified ECMWF physics',
#  'radiation': 'Modified ECMWF radiation',
#  'date_time': '20150415 135128',
#  'operating_system': 'Linux 2.6.32.59-0.3-default x86_64',
#  'user_name': 's.stadtler@fz-juelich.de,Scarlet Stadtler,1044105 (jicg2324)',
#  'host_name': 'jf51c25',
#  'jsbach_version': '2.01',
#  'truncation': 63,
#  'history': 'Thu Apr 16 16:22:08 2015: ncks -d time,0,7 homo_chem_hammoz_20141128_200312.01_echam.nc /lustre/jhome16/jicg23/jicg2300/test_echam_spectral.nc',
#  'NCO': '4.4.5'}

# %% [markdown]
# ### M-1 CRS

# %% [markdown]
# ### M-2 Number of dimensions

# %%
dimensions = ds.dimensions()
dimensions.size
# Out:
# 7

# %%
dimensions.list
# Out:
# ['time', 'lat', 'lon', 'mlev', 'ilev', 'spc', 'complex']

# %% [markdown]
# ### M-3 Properties of dimensions

# %%
dimensions.properties()
# Out:
# {'time': {'type': 'float64',
#   'size': 8,
#   'units': 'days since 2002-12-01 00:00:00',
#   'calendar': 'proleptic_gregorian'},
#  'lat': {'type': 'float64',
#   'size': 96,
#   'long_name': 'latitude',
#   'units': 'degrees_north',
#   'standard_name': 'latitude',
#   'axis': 'Y'},
#  'lon': {'type': 'float64',
#   'size': 192,
#   'long_name': 'longitude',
#   'units': 'degrees_east',
#   'standard_name': 'longitude',
#   'axis': 'X'},
#  'mlev': {'type': 'int32',
#   'size': 47,
#   'long_name': 'hybrid level at layer midpoints',
#   'standard_name': 'hybrid_sigma_pressure',
#   'units': 'level',
#   'positive': 'down',
#   'formula': 'hyam hybm (mlev=hyam+hybm*aps)',
#   'formula_terms': 'ap: hyam b: hybm ps: aps',
#   'borders': 'ilev'},
#  'ilev': {'type': 'int32',
#   'size': 48,
#   'long_name': 'hybrid level at layer interfaces',
#   'standard_name': 'hybrid_sigma_pressure',
#   'units': 'level',
#   'positive': 'down',
#   'formula': 'hyai hybi (ilev=hyai+hybi*aps)',
#   'formula_terms': 'ap: hyai b: hybi ps: aps'},
#  'spc': {'type': 'NO VARIABLE ATTRIBUTES', 'size': 2080},
#  'complex': {'type': 'NO VARIABLE ATTRIBUTES', 'size': 2}}

# %% [markdown]
# ### M-4 Number of variables

# %%
variables = ds.variables()
variables.size
# Out:
# 136

# %%
variables.list
# Out:
# ['abso4',
#  'aclcac',
#  'aclcov',
#  'ahfcon',
#  'ahfice',
#  'ahfl',
#  'ahfliac',
#  'ahfllac',
#  'ahflwac',
#  'ahfres',
#  'ahfs',
#  'ahfsiac',
#  'ahfslac',
#  'ahfswac',
#  'albedo',
#  'albedo_nir',
#  'albedo_nir_dif',
#  'albedo_nir_dir',
#  'albedo_vis',
#  'albedo_vis_dif',
#  'albedo_vis_dir',
#  'alsobs',
#  'alsoi',
#  'alsol',
#  'alsom',
#  'alsow',
#  'ameltdepth',
#  'ameltfrac',
#  'amlcorac',
#  'ao3',
#  'apmeb',
#  'apmegl',
#  'aprc',
#  'aprl',
#  'aprs',
#  'aps',
#  'az0i',
#  'az0l',
#  'az0w',
#  'barefrac',
#  'dew2',
#  'drain',
#  'evap',
#  'evapiac',
#  'evaplac',
#  'evapwac',
#  'fage',
#  'friac',
#  'geosp',
#  'glac',
#  'gld',
#  'hyai',
#  'hyam',
#  'hybi',
#  'hybm',
#  'ilev',
#  'lat',
#  'lon',
#  'lsp',
#  'mlev',
#  'q',
#  'qres',
#  'qvi',
#  'relhum',
#  'runoff',
#  'sd',
#  'seaice',
#  'siced',
#  'sicepdi',
#  'sicepdw',
#  'sicepres',
#  'slm',
#  'sn',
#  'snacl',
#  'snc',
#  'sni',
#  'snifrac',
#  'snmel',
#  'sofliac',
#  'sofllac',
#  'soflwac',
#  'srad0',
#  'srad0d',
#  'srad0u',
#  'sradl',
#  'srads',
#  'sradsu',
#  'sraf0',
#  'srafl',
#  'srafs',
#  'st',
#  'svo',
#  't2max',
#  't2min',
#  'temp2',
#  'thvsig',
#  'time',
#  'topmax',
#  'tpot',
#  'trad0',
#  'tradl',
#  'trads',
#  'tradsu',
#  'traf0',
#  'trafl',
#  'trafs',
#  'trfliac',
#  'trfllac',
#  'trflwac',
#  'tropo',
#  'tsi',
#  'tsicepdi',
#  'tslm1',
#  'tsurf',
#  'tsw',
#  'u10',
#  'ustr',
#  'ustri',
#  'ustrl',
#  'ustrw',
#  'v10',
#  'vdis',
#  'vdisgw',
#  'vstr',
#  'vstri',
#  'vstrl',
#  'vstrw',
#  'wimax',
#  'wind10',
#  'wl',
#  'ws',
#  'wsmx',
#  'xi',
#  'xivi',
#  'xl',
#  'xlvi']

# %% [markdown]
# ### M-5 Properties of variables

# %%
variables.properties()
# Out:
# {'abso4': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'antropogenic sulfur burden',
#   'units': 'kg/m**2',
#   'code': 235,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'aclcac': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'cloud cover',
#   'code': 223,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'aclcov': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'total cloud cover',
#   'code': 164,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfcon': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'conductive heat flux through ice',
#   'units': 'W/m**2',
#   'code': 208,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfice': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'conductive heat flux',
#   'units': 'W/m**2',
#   'code': 125,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'latent heat flux',
#   'units': 'W/m**2',
#   'code': 147,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfliac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'latent heat flux over ice',
#   'units': 'W/m**2',
#   'code': 110,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfllac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'latent heat flux over land',
#   'units': 'W/m**2',
#   'code': 112,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahflwac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'latent heat flux over water',
#   'units': 'W/m**2',
#   'code': 111,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfres': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'melting of ice',
#   'units': 'W/m**2',
#   'code': 209,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfs': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'sensible heat flux',
#   'units': 'W/m**2',
#   'code': 146,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfsiac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'sensible heat flux over ice',
#   'units': 'W/m**2',
#   'code': 119,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfslac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'sensible heat flux over land',
#   'units': 'W/m**2',
#   'code': 121,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ahfswac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'sensible heat flux over water',
#   'units': 'W/m**2',
#   'code': 120,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo',
#   'code': 175,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo_nir': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo NIR range',
#   'code': 101,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo_nir_dif': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo NIR range diffuse',
#   'code': 82,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo_nir_dir': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo NIR range direct',
#   'code': 80,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo_vis': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo visible range',
#   'code': 100,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo_vis_dif': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo visible range diffuse',
#   'code': 81,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'albedo_vis_dir': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface albedo visible range direct',
#   'code': 79,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'alsobs': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'albedo of bare ice and snow without ponds',
#   'code': 72,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'alsoi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'albedo of ice',
#   'code': 122,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'alsol': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'albedo of land',
#   'code': 124,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'alsom': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'albedo of melt ponds',
#   'code': 71,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'alsow': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'albedo of water',
#   'code': 123,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ameltdepth': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'total melt pond depth',
#   'units': 'm',
#   'code': 77,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ameltfrac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'fract area of melt ponds on sea-ice',
#   'code': 78,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'amlcorac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'mixed layer flux correction',
#   'units': 'W/m**2',
#   'code': 89,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ao3': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'ipcc ozone',
#   'units': 'kg/kg',
#   'code': 236,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'apmeb': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'vertic integr tendenc of water',
#   'units': 'kg/m**2s',
#   'code': 137,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'apmegl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'P-E over land ice',
#   'units': 'kg/m**2s',
#   'code': 221,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'aprc': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'convective  precipitation',
#   'units': 'kg/m**2s',
#   'code': 143,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'aprl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'large scale precipitation',
#   'units': 'kg/m**2s',
#   'code': 142,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'aprs': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'snow fall',
#   'units': 'kg/m**2s',
#   'code': 144,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'aps': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface pressure',
#   'units': 'Pa',
#   'code': 134,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'az0i': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'roughness length over ice',
#   'units': 'm',
#   'code': 116,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'az0l': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'roughness length over land',
#   'units': 'm',
#   'code': 118,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'az0w': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'roughness length over water',
#   'units': 'm',
#   'code': 117,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'barefrac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'bare ice fraction',
#   'code': 70,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'dew2': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': '2m dew point temperature',
#   'units': 'K',
#   'code': 168,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'drain': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'drainage',
#   'units': 'kg/m**2s',
#   'code': 161,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'evap': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'evaporation',
#   'units': 'kg/m**2s',
#   'code': 182,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'evapiac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'evaporation over ice',
#   'units': 'kg/m**2s',
#   'code': 113,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'evaplac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'evaporation over land',
#   'units': 'kg/m**2s',
#   'code': 115,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'evapwac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'evaporation over water',
#   'units': 'kg/m**2s',
#   'code': 114,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'fage': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'aging factor of snow on ice',
#   'code': 68,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'friac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'ice cover (fraction of grid box)',
#   'code': 97,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'geosp': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface geopotential (orography)',
#   'units': 'm**2/s**2',
#   'code': 129,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'glac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'fraction of land covered by glaciers',
#   'code': 232,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'gld': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'glacier depth',
#   'units': 'm',
#   'code': 213,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'hyai': {'dimensions': ('ilev',),
#   'type': 'float64',
#   'size': 48,
#   'long_name': 'hybrid A coefficient at layer interfaces',
#   'units': 'Pa'},
#  'hyam': {'dimensions': ('mlev',),
#   'type': 'float64',
#   'size': 47,
#   'long_name': 'hybrid A coefficient at layer midpoints',
#   'units': 'Pa'},
#  'hybi': {'dimensions': ('ilev',),
#   'type': 'float64',
#   'size': 48,
#   'long_name': 'hybrid B coefficient at layer interfaces',
#   'units': '1'},
#  'hybm': {'dimensions': ('mlev',),
#   'type': 'float64',
#   'size': 47,
#   'long_name': 'hybrid B coefficient at layer midpoints',
#   'units': '1'},
#  'ilev': {'dimensions': ('ilev',),
#   'type': 'int32',
#   'size': 48,
#   'long_name': 'hybrid level at layer interfaces',
#   'standard_name': 'hybrid_sigma_pressure',
#   'units': 'level',
#   'positive': 'down',
#   'formula': 'hyai hybi (ilev=hyai+hybi*aps)',
#   'formula_terms': 'ap: hyai b: hybi ps: aps'},
#  'lat': {'dimensions': ('lat',),
#   'type': 'float64',
#   'size': 96,
#   'long_name': 'latitude',
#   'units': 'degrees_north',
#   'standard_name': 'latitude',
#   'axis': 'Y'},
#  'lon': {'dimensions': ('lon',),
#   'type': 'float64',
#   'size': 192,
#   'long_name': 'longitude',
#   'units': 'degrees_east',
#   'standard_name': 'longitude',
#   'axis': 'X'},
#  'lsp': {'dimensions': ('time', 'spc', 'complex'),
#   'type': 'float32',
#   'size': 33280,
#   'long_name': 'log surface pressure',
#   'code': 152,
#   'table': 128,
#   'grid_type': 'spectral',
#   'axis': 'T--',
#   'truncation': 63},
#  'mlev': {'dimensions': ('mlev',),
#   'type': 'int32',
#   'size': 47,
#   'long_name': 'hybrid level at layer midpoints',
#   'standard_name': 'hybrid_sigma_pressure',
#   'units': 'level',
#   'positive': 'down',
#   'formula': 'hyam hybm (mlev=hyam+hybm*aps)',
#   'formula_terms': 'ap: hyam b: hybm ps: aps',
#   'borders': 'ilev'},
#  'q': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'specific humidity',
#   'units': 'kg/kg',
#   'code': 133,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'qres': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'residual heat flux for melting sea ice',
#   'units': 'W/m**2',
#   'code': 126,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'qvi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'vertically integrated water vapor',
#   'units': 'kg/m**2',
#   'code': 230,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'relhum': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'relative humidity',
#   'code': 157,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'runoff': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface runoff and drainage',
#   'units': 'kg/m**2s',
#   'code': 160,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sd': {'dimensions': ('time', 'mlev', 'spc', 'complex'),
#   'type': 'float32',
#   'size': 1564160,
#   'long_name': 'divergence',
#   'units': '1/s',
#   'code': 155,
#   'table': 128,
#   'grid_type': 'spectral',
#   'axis': 'TZ--',
#   'truncation': 63},
#  'seaice': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'ice cover (fraction of 1-SLM)',
#   'code': 210,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'siced': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'ice depth',
#   'units': 'm',
#   'code': 211,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sicepdi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'ice thickness on melt pond',
#   'units': 'm',
#   'code': 74,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sicepdw': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'melt pond depth on sea-ice',
#   'units': 'm',
#   'code': 73,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sicepres': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'residual heat flux',
#   'units': 'W/m**2',
#   'code': 76,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'slm': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'land sea mask (1=land, 0=sea/lakes)',
#   'code': 172,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sn': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'snow depth',
#   'units': 'm',
#   'code': 141,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'snacl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'snow accumulation over land',
#   'units': 'kg/m**2s',
#   'code': 222,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'snc': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'snow depth at the canopy',
#   'units': 'm',
#   'code': 233,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sni': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'water equivalent of snow on ice',
#   'units': 'm',
#   'code': 214,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'snifrac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'fraction of ice covered with snow',
#   'code': 69,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'snmel': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'snow melt',
#   'units': 'kg/m**2s',
#   'code': 218,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sofliac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'SW flux over ice',
#   'units': 'W/m**2',
#   'code': 94,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sofllac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'SW flux over land',
#   'units': 'W/m**2',
#   'code': 96,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'soflwac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'SW flux over water',
#   'units': 'W/m**2',
#   'code': 95,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'srad0': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net top solar radiation',
#   'units': 'W/m**2',
#   'code': 178,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'srad0d': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'top incoming solar radiation',
#   'units': 'W/m**2',
#   'code': 184,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'srad0u': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'top solar radiation upward',
#   'units': 'W/m**2',
#   'code': 203,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sradl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'solar radiation 200mb',
#   'units': 'W/m**2',
#   'code': 86,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'srads': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net surface solar radiation',
#   'units': 'W/m**2',
#   'code': 176,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sradsu': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface solar radiation upward',
#   'units': 'W/m**2',
#   'code': 204,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'sraf0': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net top solar radiation     (clear sky)',
#   'units': 'W/m**2',
#   'code': 187,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'srafl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'solar radiation 200mb (clear sky)',
#   'units': 'W/m**2',
#   'code': 88,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'srafs': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net surface solar radiation (clear sky)',
#   'units': 'W/m**2',
#   'code': 185,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'st': {'dimensions': ('time', 'mlev', 'spc', 'complex'),
#   'type': 'float32',
#   'size': 1564160,
#   'long_name': 'temperature',
#   'units': 'K',
#   'code': 130,
#   'table': 128,
#   'grid_type': 'spectral',
#   'axis': 'TZ--',
#   'truncation': 63},
#  'svo': {'dimensions': ('time', 'mlev', 'spc', 'complex'),
#   'type': 'float32',
#   'size': 1564160,
#   'long_name': 'vorticity',
#   'units': '1/s',
#   'code': 138,
#   'table': 128,
#   'grid_type': 'spectral',
#   'axis': 'TZ--',
#   'truncation': 63},
#  't2max': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'maximum 2m temperature',
#   'units': 'K',
#   'code': 201,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  't2min': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'minimum 2m temperature',
#   'units': 'K',
#   'code': 202,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'temp2': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': '2m temperature',
#   'units': 'K',
#   'code': 167,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'thvsig': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'stddev virt pot temp at halflev klevm1',
#   'units': 'K',
#   'code': 238,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'time': {'dimensions': ('time',),
#   'type': 'float64',
#   'size': 8,
#   'units': 'days since 2002-12-01 00:00:00',
#   'calendar': 'proleptic_gregorian'},
#  'topmax': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'max height of conv cloud tops',
#   'units': 'Pa',
#   'code': 217,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tpot': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'potential temperature',
#   'units': 'K',
#   'code': 239,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trad0': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'top thermal radiation (OLR)',
#   'units': 'W/m**2',
#   'code': 179,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tradl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'thermal radiation 200mb',
#   'units': 'W/m**2',
#   'code': 85,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trads': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net surface thermal radiation',
#   'units': 'W/m**2',
#   'code': 177,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tradsu': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface thermal radiation upward',
#   'units': 'W/m**2',
#   'code': 205,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'traf0': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net top thermal radiation   (clear sky)',
#   'units': 'W/m**2',
#   'code': 188,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trafl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'thermal radiation 200mb (clear sky)',
#   'units': 'W/m**2',
#   'code': 87,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trafs': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'net surface therm radiation (clear sky)',
#   'units': 'W/m**2',
#   'code': 186,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trfliac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'LW flux over ice',
#   'units': 'W/m**2',
#   'code': 91,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trfllac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'LW flux over land',
#   'units': 'W/m**2',
#   'code': 93,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'trflwac': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'LW flux over water',
#   'units': 'W/m**2',
#   'code': 92,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tropo': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'WMO defined tropopause height',
#   'units': 'Pa',
#   'code': 237,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tsi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface temperature of ice',
#   'units': 'K',
#   'code': 102,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tsicepdi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'ice temperature on frozen melt pond',
#   'units': 'K',
#   'code': 75,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tslm1': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface temperature of land',
#   'units': 'K',
#   'code': 139,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tsurf': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface temperature',
#   'units': 'K',
#   'code': 169,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'tsw': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'surface temperature of water',
#   'units': 'K',
#   'code': 103,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'u10': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': '10m u-velocity',
#   'units': 'm/s',
#   'code': 165,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ustr': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'u-stress',
#   'units': 'Pa',
#   'code': 180,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ustri': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'zonal      wind stress over ice',
#   'units': 'Pa',
#   'code': 104,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ustrl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'zonal      wind stress over land',
#   'units': 'Pa',
#   'code': 108,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ustrw': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'zonal      wind stress over water',
#   'units': 'Pa',
#   'code': 106,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'v10': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': '10m v-velocity',
#   'units': 'm/s',
#   'code': 166,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'vdis': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'boundary layer dissipation',
#   'units': 'W/m**2',
#   'code': 145,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'vdisgw': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'gravity wave dissipation',
#   'units': 'W/m**2',
#   'code': 197,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'vstr': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'v-stress',
#   'units': 'Pa',
#   'code': 181,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'vstri': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'meridional wind stress over ice',
#   'units': 'Pa',
#   'code': 105,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'vstrl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'meridional wind stress over land',
#   'units': 'Pa',
#   'code': 109,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'vstrw': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'meridional wind stress over water',
#   'units': 'Pa',
#   'code': 107,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'wimax': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'maximum 10m-wind speed',
#   'units': 'm/s',
#   'code': 216,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'wind10': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': '10m windspeed',
#   'units': 'm/s',
#   'code': 171,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'wl': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'skin reservoir content',
#   'units': 'm',
#   'code': 193,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'ws': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'soil wetness',
#   'units': 'm',
#   'code': 140,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'wsmx': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'field capacity of soil',
#   'units': 'm',
#   'code': 229,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'xi': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'cloud ice',
#   'units': 'kg/kg',
#   'code': 154,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'xivi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'vertically integrated cloud ice',
#   'units': 'kg/m**2',
#   'code': 150,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'xl': {'dimensions': ('time', 'mlev', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 6930432,
#   'long_name': 'cloud water',
#   'units': 'kg/kg',
#   'code': 153,
#   'table': 128,
#   'grid_type': 'gaussian'},
#  'xlvi': {'dimensions': ('time', 'lat', 'lon'),
#   'type': 'float32',
#   'size': 147456,
#   'long_name': 'vertically integrated cloud water',
#   'units': 'kg/m**2',
#   'code': 231,
#   'table': 128,
#   'grid_type': 'gaussian'}}

# %% [markdown]
# ### M-6 Spatial Extent

# %%
ds.mbr()
# Out:
# 'POLYGON ((358.125 -88.5722, 358.125 88.5722, 0 88.5722, 0 -88.5722, 358.125 -88.5722))'

# %% [markdown]
# ### M-7 Temporal period

# %%
ds.time_extent()
# Out:
# '365.000000 - 365.875000 days since 2002-12-01 00:00:00'

# %% [markdown]
# ### M-8 Histogram

# %% [markdown]
# ### M-9 No Data Values

# %%
ds.no_data_values()
# Out:
# {'abso4': 1e+20,
#  'aclcac': 1e+20,
#  'aclcov': 1e+20,
#  'ahfcon': 1e+20,
#  'ahfice': 1e+20,
#  'ahfl': 1e+20,
#  'ahfliac': 1e+20,
#  'ahfllac': 1e+20,
#  'ahflwac': 1e+20,
#  'ahfres': 1e+20,
#  'ahfs': 1e+20,
#  'ahfsiac': 1e+20,
#  'ahfslac': 1e+20,
#  'ahfswac': 1e+20,
#  'albedo': 1e+20,
#  'albedo_nir': 1e+20,
#  'albedo_nir_dif': 1e+20,
#  'albedo_nir_dir': 1e+20,
#  'albedo_vis': 1e+20,
#  'albedo_vis_dif': 1e+20,
#  'albedo_vis_dir': 1e+20,
#  'alsobs': 1e+20,
#  'alsoi': 1e+20,
#  'alsol': 1e+20,
#  'alsom': 1e+20,
#  'alsow': 1e+20,
#  'ameltdepth': 1e+20,
#  'ameltfrac': 1e+20,
#  'amlcorac': 1e+20,
#  'ao3': 1e+20,
#  'apmeb': 1e+20,
#  'apmegl': 1e+20,
#  'aprc': 1e+20,
#  'aprl': 1e+20,
#  'aprs': 1e+20,
#  'aps': 1e+20,
#  'az0i': 1e+20,
#  'az0l': 1e+20,
#  'az0w': 1e+20,
#  'barefrac': 1e+20,
#  'dew2': 1e+20,
#  'drain': 1e+20,
#  'evap': 1e+20,
#  'evapiac': 1e+20,
#  'evaplac': 1e+20,
#  'evapwac': 1e+20,
#  'fage': 1e+20,
#  'friac': 1e+20,
#  'geosp': 1e+20,
#  'glac': 1e+20,
#  'gld': 1e+20,
#  'hyai': 1e+20,
#  'hyam': 1e+20,
#  'hybi': 1e+20,
#  'hybm': 1e+20,
#  'ilev': 999999,
#  'lat': 1e+20,
#  'lon': 1e+20,
#  'lsp': 1e+20,
#  'mlev': 999999,
#  'q': 1e+20,
#  'qres': 1e+20,
#  'qvi': 1e+20,
#  'relhum': 1e+20,
#  'runoff': 1e+20,
#  'sd': 1e+20,
#  'seaice': 1e+20,
#  'siced': 1e+20,
#  'sicepdi': 1e+20,
#  'sicepdw': 1e+20,
#  'sicepres': 1e+20,
#  'slm': 1e+20,
#  'sn': 1e+20,
#  'snacl': 1e+20,
#  'snc': 1e+20,
#  'sni': 1e+20,
#  'snifrac': 1e+20,
#  'snmel': 1e+20,
#  'sofliac': 1e+20,
#  'sofllac': 1e+20,
#  'soflwac': 1e+20,
#  'srad0': 1e+20,
#  'srad0d': 1e+20,
#  'srad0u': 1e+20,
#  'sradl': 1e+20,
#  'srads': 1e+20,
#  'sradsu': 1e+20,
#  'sraf0': 1e+20,
#  'srafl': 1e+20,
#  'srafs': 1e+20,
#  'st': 1e+20,
#  'svo': 1e+20,
#  't2max': 1e+20,
#  't2min': 1e+20,
#  'temp2': 1e+20,
#  'thvsig': 1e+20,
#  'time': 1e+20,
#  'topmax': 1e+20,
#  'tpot': 1e+20,
#  'trad0': 1e+20,
#  'tradl': 1e+20,
#  'trads': 1e+20,
#  'tradsu': 1e+20,
#  'traf0': 1e+20,
#  'trafl': 1e+20,
#  'trafs': 1e+20,
#  'trfliac': 1e+20,
#  'trfllac': 1e+20,
#  'trflwac': 1e+20,
#  'tropo': 1e+20,
#  'tsi': 1e+20,
#  'tsicepdi': 1e+20,
#  'tslm1': 1e+20,
#  'tsurf': 1e+20,
#  'tsw': 1e+20,
#  'u10': 1e+20,
#  'ustr': 1e+20,
#  'ustri': 1e+20,
#  'ustrl': 1e+20,
#  'ustrw': 1e+20,
#  'v10': 1e+20,
#  'vdis': 1e+20,
#  'vdisgw': 1e+20,
#  'vstr': 1e+20,
#  'vstri': 1e+20,
#  'vstrl': 1e+20,
#  'vstrw': 1e+20,
#  'wimax': 1e+20,
#  'wind10': 1e+20,
#  'wl': 1e+20,
#  'ws': 1e+20,
#  'wsmx': 1e+20,
#  'xi': 1e+20,
#  'xivi': 1e+20,
#  'xl': 1e+20,
#  'xlvi': 1e+20}

# %% [markdown]
# ### M-10 Sample

# %%
ds.sample([-20, -20, 20, 20])
# Out:
# Wrote file sample.nc, 30199704 bytes.

# %% [markdown]
# ### Statistics

# %%
ds.stats()
# Out:
# {'abso4': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.0,
#   'mean': 0.0,
#   'std': 0.0,
#   'variance': 0.0,
#   'contiguous': True},
#  'aclcac': {'count': 6930432,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.07694961130619049,
#   'std': 0.24717986583709717,
#   'variance': 0.0610978864133358,
#   'contiguous': True},
#  'aclcov': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.658626139163971,
#   'std': 0.42908573150634766,
#   'variance': 0.18411457538604736,
#   'contiguous': True},
#  'ahfcon': {'count': 147456,
#   'missing': 0,
#   'min': -49.306392669677734,
#   'max': 3.4396021366119385,
#   'mean': -1.3955096006393433,
#   'std': 4.767168045043945,
#   'variance': 22.72589111328125,
#   'contiguous': True},
#  'ahfice': {'count': 147456,
#   'missing': 0,
#   'min': -49.32128143310547,
#   'max': 3.8331120014190674,
#   'mean': -1.7411147356033325,
#   'std': 5.261457443237305,
#   'variance': 27.682933807373047,
#   'contiguous': True},
#  'ahfl': {'count': 147456,
#   'missing': 0,
#   'min': -813.099609375,
#   'max': 82.4598159790039,
#   'mean': -62.63431930541992,
#   'std': 87.39911651611328,
#   'variance': 7638.60595703125,
#   'contiguous': True},
#  'ahfliac': {'count': 147456,
#   'missing': 0,
#   'min': -68.75636291503906,
#   'max': 15.714940071105957,
#   'mean': -0.3944023847579956,
#   'std': 3.102940320968628,
#   'variance': 9.628238677978516,
#   'contiguous': True},
#  'ahfllac': {'count': 147456,
#   'missing': 0,
#   'min': -726.924560546875,
#   'max': 21.802961349487305,
#   'mean': -6.392294883728027,
#   'std': 39.11774444580078,
#   'variance': 1530.1978759765625,
#   'contiguous': True},
#  'ahflwac': {'count': 147456,
#   'missing': 0,
#   'min': -813.099609375,
#   'max': 82.4598159790039,
#   'mean': -55.847618103027344,
#   'std': 82.81635284423828,
#   'variance': 6858.548828125,
#   'contiguous': True},
#  'ahfres': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 160.8815155029297,
#   'mean': 0.08225465565919876,
#   'std': 2.1089413166046143,
#   'variance': 4.447633743286133,
#   'contiguous': True},
#  'ahfs': {'count': 147456,
#   'missing': 0,
#   'min': -645.7228393554688,
#   'max': 177.72564697265625,
#   'mean': -12.255952835083008,
#   'std': 49.64640426635742,
#   'variance': 2464.765625,
#   'contiguous': True},
#  'ahfsiac': {'count': 147456,
#   'missing': 0,
#   'min': -77.87291717529297,
#   'max': 92.49027252197266,
#   'mean': 0.3654521703720093,
#   'std': 5.394466876983643,
#   'variance': 29.100271224975586,
#   'contiguous': True},
#  'ahfslac': {'count': 147456,
#   'missing': 0,
#   'min': -645.7228393554688,
#   'max': 177.72564697265625,
#   'mean': -2.8844716548919678,
#   'std': 42.30205535888672,
#   'variance': 1789.4638671875,
#   'contiguous': True},
#  'ahfswac': {'count': 147456,
#   'missing': 0,
#   'min': -355.47198486328125,
#   'max': 118.1556167602539,
#   'mean': -9.736933708190918,
#   'std': 26.5065860748291,
#   'variance': 702.5990600585938,
#   'contiguous': True},
#  'albedo': {'count': 147456,
#   'missing': 0,
#   'min': 0.02831892855465412,
#   'max': 0.9350595474243164,
#   'mean': 0.3263351023197174,
#   'std': 0.30492228269577026,
#   'variance': 0.0929775983095169,
#   'contiguous': True},
#  'albedo_nir': {'count': 147456,
#   'missing': 0,
#   'min': 0.01898474432528019,
#   'max': 0.9350595474243164,
#   'mean': 0.32558706402778625,
#   'std': 0.2849079370498657,
#   'variance': 0.08117253333330154,
#   'contiguous': True},
#  'albedo_nir_dif': {'count': 147456,
#   'missing': 0,
#   'min': 0.03943979740142822,
#   'max': 0.9350595474243164,
#   'mean': 0.2965834438800812,
#   'std': 0.29827427864074707,
#   'variance': 0.08896754682064056,
#   'contiguous': True},
#  'albedo_nir_dir': {'count': 147456,
#   'missing': 0,
#   'min': 0.017415108159184456,
#   'max': 0.9350595474243164,
#   'mean': 0.33328577876091003,
#   'std': 0.28305816650390625,
#   'variance': 0.08012191951274872,
#   'contiguous': True},
#  'albedo_vis': {'count': 147456,
#   'missing': 0,
#   'min': 0.031196683645248413,
#   'max': 0.9593837857246399,
#   'mean': 0.32394400238990784,
#   'std': 0.328838974237442,
#   'variance': 0.10813507437705994,
#   'contiguous': True},
#  'albedo_vis_dif': {'count': 147456,
#   'missing': 0,
#   'min': 0.031196683645248413,
#   'max': 0.9593837857246399,
#   'mean': 0.2954173982143402,
#   'std': 0.3409520983695984,
#   'variance': 0.11624833941459656,
#   'contiguous': True},
#  'albedo_vis_dir': {'count': 147456,
#   'missing': 0,
#   'min': 0.031196683645248413,
#   'max': 0.9627472758293152,
#   'mean': 0.3364783525466919,
#   'std': 0.3254237473011017,
#   'variance': 0.10590061545372009,
#   'contiguous': True},
#  'alsobs': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.9437975287437439,
#   'mean': 0.3424050509929657,
#   'std': 0.24948540329933167,
#   'variance': 0.06224296987056732,
#   'contiguous': True},
#  'alsoi': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.9437975287437439,
#   'mean': 0.34239110350608826,
#   'std': 0.24947099387645721,
#   'variance': 0.06223578006029129,
#   'contiguous': True},
#  'alsol': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.8672744035720825,
#   'mean': 0.16093508899211884,
#   'std': 0.28559598326683044,
#   'variance': 0.08156506717205048,
#   'contiguous': True},
#  'alsom': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.30638158321380615,
#   'mean': 0.00011325500963721424,
#   'std': 0.0051124198362231255,
#   'variance': 2.613683682284318e-05,
#   'contiguous': True},
#  'alsow': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.3404196500778198,
#   'mean': 0.0947408378124237,
#   'std': 0.0880703404545784,
#   'variance': 0.007756384555250406,
#   'contiguous': True},
#  'ameltdepth': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.3188796043395996,
#   'mean': 0.0003731515898834914,
#   'std': 0.016963528469204903,
#   'variance': 0.00028776127146556973,
#   'contiguous': True},
#  'ameltfrac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.2831585109233856,
#   'mean': 3.3831358450697735e-05,
#   'std': 0.002307330025359988,
#   'variance': 5.3237713473208714e-06,
#   'contiguous': True},
#  'amlcorac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.0,
#   'mean': 0.0,
#   'std': 0.0,
#   'variance': 0.0,
#   'contiguous': True},
#  'ao3': {'count': 6930432,
#   'missing': 0,
#   'min': 1.0973325359486807e-08,
#   'max': 1.5760591850266792e-05,
#   'mean': 2.6296547730453312e-06,
#   'std': 4.018896561319707e-06,
#   'variance': 1.6151529766417205e-11,
#   'contiguous': True},
#  'apmeb': {'count': 147456,
#   'missing': 0,
#   'min': -0.0019679281394928694,
#   'max': 0.0020781122148036957,
#   'mean': -2.458248218317749e-06,
#   'std': 0.0001399513566866517,
#   'variance': 1.958638051746675e-08,
#   'contiguous': True},
#  'apmegl': {'count': 147456,
#   'missing': 0,
#   'min': -1.3496556675818283e-05,
#   'max': 0.00022943491057958454,
#   'mean': 5.347775413611089e-07,
#   'std': 4.67952668259386e-06,
#   'variance': 2.189796954876755e-11,
#   'contiguous': True},
#  'aprc': {'count': 147456,
#   'missing': 0,
#   'min': -1.1764346577294272e-23,
#   'max': 0.00148605031426996,
#   'mean': 1.5825618902454153e-05,
#   'std': 7.364900375250727e-05,
#   'variance': 5.424175331114611e-09,
#   'contiguous': True},
#  'aprl': {'count': 147456,
#   'missing': 0,
#   'min': 1.525706205520503e-18,
#   'max': 0.001650406513363123,
#   'mean': 1.1579073543543927e-05,
#   'std': 5.12042133777868e-05,
#   'variance': 2.62187160871008e-09,
#   'contiguous': True},
#  'aprs': {'count': 147456,
#   'missing': 0,
#   'min': 1.5061842335165173e-30,
#   'max': 0.00047183968126773834,
#   'mean': 3.7622817217197735e-06,
#   'std': 1.6222160411416553e-05,
#   'variance': 2.6315846723967695e-10,
#   'contiguous': True},
#  'aps': {'count': 147456,
#   'missing': 0,
#   'min': 51751.7734375,
#   'max': 108104.1640625,
#   'mean': 96606.3359375,
#   'std': 9382.0859375,
#   'variance': 88023536.0,
#   'contiguous': True},
#  'az0i': {'count': 147456,
#   'missing': 0,
#   'min': 0.0010000000474974513,
#   'max': 0.0010000000474974513,
#   'mean': 0.0010000000474974513,
#   'std': 0.0,
#   'variance': 0.0,
#   'contiguous': True},
#  'az0l': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 20.013916015625,
#   'mean': 0.30083075165748596,
#   'std': 1.3314948081970215,
#   'variance': 1.7728784084320068,
#   'contiguous': True},
#  'az0w': {'count': 147456,
#   'missing': 0,
#   'min': 1.4999999621068127e-05,
#   'max': 0.002684404142200947,
#   'mean': 0.00023639906430616975,
#   'std': 0.0002211262471973896,
#   'variance': 4.88968190381911e-08,
#   'contiguous': True},
#  'barefrac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.8709816336631775,
#   'std': 0.33435922861099243,
#   'variance': 0.11179608851671219,
#   'contiguous': True},
#  'dew2': {'count': 147456,
#   'missing': 0,
#   'min': 221.30532836914062,
#   'max': 301.9994201660156,
#   'mean': 273.5295715332031,
#   'std': 19.5949649810791,
#   'variance': 383.962646484375,
#   'contiguous': True},
#  'drain': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 2.7777778086601757e-05,
#   'mean': 2.7070257146988297e-07,
#   'std': 2.2146725768834585e-06,
#   'variance': 4.904774936892453e-12,
#   'contiguous': True},
#  'evap': {'count': 147456,
#   'missing': 0,
#   'min': -0.00032513579935766757,
#   'max': 3.297337389085442e-05,
#   'mean': -2.5016544896061532e-05,
#   'std': 3.4958684409502894e-05,
#   'variance': 1.2221096357123429e-09,
#   'contiguous': True},
#  'evapiac': {'count': 147456,
#   'missing': 0,
#   'min': -2.425696402497124e-05,
#   'max': 5.5441664699174e-06,
#   'mean': -1.3914355179167615e-07,
#   'std': 1.0947045439024805e-06,
#   'variance': 1.1983780938071287e-12,
#   'contiguous': True},
#  'evaplac': {'count': 147456,
#   'missing': 0,
#   'min': -0.00029067680588923395,
#   'max': 8.6900017777225e-06,
#   'mean': -2.545500592532335e-06,
#   'std': 1.563305704621598e-05,
#   'variance': 2.443924507211648e-10,
#   'contiguous': True},
#  'evapwac': {'count': 147456,
#   'missing': 0,
#   'min': -0.00032513579935766757,
#   'max': 3.297337389085442e-05,
#   'mean': -2.2331898435368203e-05,
#   'std': 3.3115942642325535e-05,
#   'variance': 1.096665647182249e-09,
#   'contiguous': True},
#  'fage': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.45357444882392883,
#   'mean': 0.010696347802877426,
#   'std': 0.041577573865652084,
#   'variance': 0.0017286946531385183,
#   'contiguous': True},
#  'friac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.11432421207427979,
#   'std': 0.30245041847229004,
#   'variance': 0.09147625416517258,
#   'contiguous': True},
#  'geosp': {'count': 147456,
#   'missing': 0,
#   'min': -5134.390625,
#   'max': 53852.609375,
#   'mean': 3635.361083984375,
#   'std': 8059.67919921875,
#   'variance': 64958428.0,
#   'contiguous': True},
#  'glac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.1112196147441864,
#   'std': 0.31440386176109314,
#   'variance': 0.09884979575872421,
#   'contiguous': True},
#  'gld': {'count': 147456,
#   'missing': 0,
#   'min': -6.618044853210449,
#   'max': 1.040482997894287,
#   'mean': 0.01229014154523611,
#   'std': 0.10981597006320953,
#   'variance': 0.012059547938406467,
#   'contiguous': True},
#  'hyai': {'count': 48,
#   'missing': 0,
#   'min': 0.0,
#   'max': 16465.0,
#   'mean': 5444.17293505941,
#   'std': 5893.306815949984,
#   'variance': 34731065.22692254,
#   'contiguous': True},
#  'hyam': {'count': 47,
#   'missing': 0,
#   'min': 0.0,
#   'max': 16381.310000000001,
#   'mean': 5560.0064017628,
#   'std': 5883.632583654313,
#   'variance': 34617132.37943872,
#   'contiguous': True},
#  'hybi': {'count': 48,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.2558895833333333,
#   'std': 0.34959658908494284,
#   'variance': 0.12221777509982638,
#   'contiguous': True},
#  'hybm': {'count': 47,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.99615,
#   'mean': 0.25069574468085104,
#   'std': 0.34344253566068544,
#   'variance': 0.1179527753010412,
#   'contiguous': True},
#  'ilev': {'count': 48,
#   'missing': 0,
#   'min': 1,
#   'max': 48,
#   'mean': 24.5,
#   'std': 13.853399101544236,
#   'variance': 191.91666666666666,
#   'contiguous': True},
#  'lat': {'count': 96,
#   'missing': 0,
#   'min': -88.57216851400727,
#   'max': 88.57216851400727,
#   'mean': -1.4802973661668755e-15,
#   'std': 51.686320913602025,
#   'variance': 2671.4757695838543,
#   'contiguous': True},
#  'lon': {'count': 192,
#   'missing': 0,
#   'min': 0.0,
#   'max': 358.125,
#   'mean': 179.0625,
#   'std': 103.92163889801778,
#   'variance': 10799.70703125,
#   'contiguous': True},
#  'lsp': {'count': 33280,
#   'missing': 0,
#   'min': -0.01986239291727543,
#   'max': 11.495631217956543,
#   'mean': 0.0027703798841685057,
#   'std': 0.1782129853963852,
#   'variance': 0.03175986930727959,
#   'contiguous': True},
#  'mlev': {'count': 47,
#   'missing': 0,
#   'min': 1,
#   'max': 47,
#   'mean': 24.0,
#   'std': 13.564659966250536,
#   'variance': 184.0,
#   'contiguous': True},
#  'q': {'count': 6930432,
#   'missing': 0,
#   'min': 6.124670193230486e-08,
#   'max': 0.022733192890882492,
#   'mean': 0.0011596620315685868,
#   'std': 0.002998367417603731,
#   'variance': 8.990206879389007e-06,
#   'contiguous': True},
#  'qres': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 230.5634307861328,
#   'mean': 0.055862169712781906,
#   'std': 2.7799623012542725,
#   'variance': 7.728190898895264,
#   'contiguous': True},
#  'qvi': {'count': 147456,
#   'missing': 0,
#   'min': 0.16271762549877167,
#   'max': 70.2603988647461,
#   'mean': 18.12044334411621,
#   'std': 16.799604415893555,
#   'variance': 282.2266845703125,
#   'contiguous': True},
#  'relhum': {'count': 6930432,
#   'missing': 0,
#   'min': 1.8023055190496962e-06,
#   'max': 1.0,
#   'mean': 0.3363105356693268,
#   'std': 0.38111644983291626,
#   'variance': 0.14524975419044495,
#   'contiguous': True},
#  'runoff': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.000948749016970396,
#   'mean': 1.0258136171614751e-06,
#   'std': 1.5410520063596778e-05,
#   'variance': 2.3748411570601036e-10,
#   'contiguous': True},
#  'sd': {'count': 1564160,
#   'missing': 0,
#   'min': -4.198668648314197e-06,
#   'max': 4.224240456096595e-06,
#   'mean': 1.1092286811287266e-10,
#   'std': 1.6528217372524523e-07,
#   'variance': 2.7318198294852894e-14,
#   'contiguous': True},
#  'seaice': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.13163679838180542,
#   'std': 0.32087165117263794,
#   'variance': 0.10295861959457397,
#   'contiguous': True},
#  'siced': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 2.0,
#   'mean': 0.2583564519882202,
#   'std': 0.6290357112884521,
#   'variance': 0.39568594098091125,
#   'contiguous': True},
#  'sicepdi': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.09622596949338913,
#   'mean': 3.1301024137064815e-05,
#   'std': 0.0015426314203068614,
#   'variance': 2.3797117592039285e-06,
#   'contiguous': True},
#  'sicepdw': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.3016960620880127,
#   'mean': 0.0003444485191721469,
#   'std': 0.015984969213604927,
#   'variance': 0.00025551923317834735,
#   'contiguous': True},
#  'sicepres': {'count': 147456,
#   'missing': 0,
#   'min': -5044.55224609375,
#   'max': 5084.576171875,
#   'mean': -11.778644561767578,
#   'std': 308.6036682128906,
#   'variance': 95236.2265625,
#   'contiguous': True},
#  'slm': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.3375650942325592,
#   'std': 0.4728793799877167,
#   'variance': 0.223614901304245,
#   'contiguous': True},
#  'sn': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.15205775201320648,
#   'mean': 0.003385942429304123,
#   'std': 0.014429288916289806,
#   'variance': 0.0002082043793052435,
#   'contiguous': True},
#  'snacl': {'count': 147456,
#   'missing': 0,
#   'min': -0.0007043996592983603,
#   'max': 0.00046721359831281006,
#   'mean': 8.2989430438829e-07,
#   'std': 1.270490884053288e-05,
#   'variance': 1.6141470104980016e-10,
#   'contiguous': True},
#  'snc': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.0,
#   'mean': 0.0,
#   'std': 0.0,
#   'variance': 0.0,
#   'contiguous': True},
#  'sni': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.5,
#   'mean': 0.022520385682582855,
#   'std': 0.07677896320819855,
#   'variance': 0.0058950092643499374,
#   'contiguous': True},
#  'snifrac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.0,
#   'mean': 0.1289844810962677,
#   'std': 0.33435988426208496,
#   'variance': 0.11179652810096741,
#   'contiguous': True},
#  'snmel': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.0006852014921605587,
#   'mean': 2.6573624722914246e-07,
#   'std': 7.437984095304273e-06,
#   'variance': 5.5323610276269974e-11,
#   'contiguous': True},
#  'sofliac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 344.8888244628906,
#   'mean': 2.310124397277832,
#   'std': 14.35124397277832,
#   'variance': 205.9582061767578,
#   'contiguous': True},
#  'sofllac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 954.4046020507812,
#   'mean': 28.031843185424805,
#   'std': 100.12638092041016,
#   'variance': 10025.2919921875,
#   'contiguous': True},
#  'soflwac': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1077.838623046875,
#   'mean': 104.54022979736328,
#   'std': 219.7865753173828,
#   'variance': 48306.140625,
#   'contiguous': True},
#  'srad0': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1281.6329345703125,
#   'mean': 201.71929931640625,
#   'std': 305.538330078125,
#   'variance': 93353.6640625,
#   'contiguous': True},
#  'srad0d': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1369.3477783203125,
#   'mean': 322.05816650390625,
#   'std': 407.40216064453125,
#   'variance': 165976.53125,
#   'contiguous': True},
#  'srad0u': {'count': 147456,
#   'missing': 0,
#   'min': -945.2841186523438,
#   'max': 0.0,
#   'mean': -120.33882904052734,
#   'std': 167.39498901367188,
#   'variance': 28021.083984375,
#   'contiguous': True},
#  'sradl': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1236.8902587890625,
#   'mean': 185.8367156982422,
#   'std': 291.1021423339844,
#   'variance': 84740.453125,
#   'contiguous': True},
#  'srads': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1077.838623046875,
#   'mean': 134.8822021484375,
#   'std': 229.07611083984375,
#   'variance': 52475.8671875,
#   'contiguous': True},
#  'sradsu': {'count': 147456,
#   'missing': 0,
#   'min': -787.6595458984375,
#   'max': 0.0,
#   'mean': -55.599937438964844,
#   'std': 123.05661010742188,
#   'variance': 15142.9287109375,
#   'contiguous': True},
#  'sraf0': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1281.9825439453125,
#   'mean': 241.10357666015625,
#   'std': 354.3243103027344,
#   'variance': 125545.7109375,
#   'contiguous': True},
#  'srafl': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1237.4967041015625,
#   'mean': 226.03211975097656,
#   'std': 340.25274658203125,
#   'variance': 115771.9375,
#   'contiguous': True},
#  'srafs': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1077.838623046875,
#   'mean': 177.28387451171875,
#   'std': 278.2027587890625,
#   'variance': 77396.78125,
#   'contiguous': True},
#  'st': {'count': 1564160,
#   'missing': 0,
#   'min': -14.303218841552734,
#   'max': 286.33251953125,
#   'mean': 0.05714020878076553,
#   'std': 3.777360677719116,
#   'variance': 14.268453598022461,
#   'contiguous': True},
#  'svo': {'count': 1564160,
#   'missing': 0,
#   'min': -1.1289532267255709e-05,
#   'max': 1.23729632832692e-05,
#   'mean': -7.427928272463191e-10,
#   'std': 3.4707946383605304e-07,
#   'variance': 1.204641583967686e-13,
#   'contiguous': True},
#  't2max': {'count': 147456,
#   'missing': 0,
#   'min': 221.95150756835938,
#   'max': 317.6504821777344,
#   'mean': 277.4102783203125,
#   'std': 21.24812126159668,
#   'variance': 451.4826354980469,
#   'contiguous': True},
#  't2min': {'count': 147456,
#   'missing': 0,
#   'min': 221.30532836914062,
#   'max': 316.3831481933594,
#   'mean': 276.7586364746094,
#   'std': 21.27642250061035,
#   'variance': 452.6861267089844,
#   'contiguous': True},
#  'temp2': {'count': 147456,
#   'missing': 0,
#   'min': 221.30532836914062,
#   'max': 317.3605041503906,
#   'mean': 277.0811767578125,
#   'std': 21.276330947875977,
#   'variance': 452.6822204589844,
#   'contiguous': True},
#  'thvsig': {'count': 147456,
#   'missing': 0,
#   'min': 9.999999747378752e-06,
#   'max': 12.689120292663574,
#   'mean': 0.24221406877040863,
#   'std': 0.4433612823486328,
#   'variance': 0.19656921923160553,
#   'contiguous': True},
#  'time': {'count': 8,
#   'missing': 0,
#   'min': 365.0,
#   'max': 365.875,
#   'mean': 365.4375,
#   'std': 0.28641098093474,
#   'variance': 0.08203125,
#   'contiguous': True},
#  'topmax': {'count': 147456,
#   'missing': 0,
#   'min': 10013.48828125,
#   'max': 99999.0,
#   'mean': 80680.1875,
#   'std': 24239.919921875,
#   'variance': 587573760.0,
#   'contiguous': True},
#  'tpot': {'count': 6930432,
#   'missing': 0,
#   'min': 234.6403350830078,
#   'max': 6850.9287109375,
#   'mean': 861.8312377929688,
#   'std': 1060.5042724609375,
#   'variance': 1124669.375,
#   'contiguous': True},
#  'trad0': {'count': 147456,
#   'missing': 0,
#   'min': -368.3294677734375,
#   'max': -102.36803436279297,
#   'mean': -220.75137329101562,
#   'std': 48.58848571777344,
#   'variance': 2360.841064453125,
#   'contiguous': True},
#  'tradl': {'count': 147456,
#   'missing': 0,
#   'min': -358.90924072265625,
#   'max': -38.51237106323242,
#   'mean': -199.92947387695312,
#   'std': 53.655487060546875,
#   'variance': 2878.9111328125,
#   'contiguous': True},
#  'trads': {'count': 147456,
#   'missing': 0,
#   'min': -236.80807495117188,
#   'max': 37.33270263671875,
#   'mean': -51.83277893066406,
#   'std': 33.84986114501953,
#   'variance': 1145.8131103515625,
#   'contiguous': True},
#  'tradsu': {'count': 147456,
#   'missing': 0,
#   'min': -655.0737915039062,
#   'max': -134.07388305664062,
#   'mean': -348.70794677734375,
#   'std': 99.29695129394531,
#   'variance': 9859.884765625,
#   'contiguous': True},
#  'traf0': {'count': 147456,
#   'missing': 0,
#   'min': -368.3294677734375,
#   'max': -142.08926391601562,
#   'mean': -241.7063751220703,
#   'std': 42.12686538696289,
#   'variance': 1774.6728515625,
#   'contiguous': True},
#  'trafl': {'count': 147456,
#   'missing': 0,
#   'min': -358.90924072265625,
#   'max': -107.6280517578125,
#   'mean': -221.92620849609375,
#   'std': 46.62333679199219,
#   'variance': 2173.735595703125,
#   'contiguous': True},
#  'trafs': {'count': 147456,
#   'missing': 0,
#   'min': -237.7398681640625,
#   'max': -26.969566345214844,
#   'mean': -82.05897521972656,
#   'std': 20.721649169921875,
#   'variance': 429.38671875,
#   'contiguous': True},
#  'trfliac': {'count': 147456,
#   'missing': 0,
#   'min': -105.88300323486328,
#   'max': 22.415401458740234,
#   'mean': -3.694031238555908,
#   'std': 13.015398979187012,
#   'variance': 169.40061950683594,
#   'contiguous': True},
#  'trfllac': {'count': 147456,
#   'missing': 0,
#   'min': -236.80807495117188,
#   'max': 37.33270263671875,
#   'mean': -19.205188751220703,
#   'std': 34.32695007324219,
#   'variance': 1178.3394775390625,
#   'contiguous': True},
#  'trflwac': {'count': 147456,
#   'missing': 0,
#   'min': -170.7610626220703,
#   'max': 20.001705169677734,
#   'mean': -28.93355941772461,
#   'std': 34.66046905517578,
#   'variance': 1201.34814453125,
#   'contiguous': True},
#  'tropo': {'count': 147456,
#   'missing': 0,
#   'min': 6488.17822265625,
#   'max': 47265.2265625,
#   'mean': 18972.697265625,
#   'std': 7230.53076171875,
#   'variance': 52280572.0,
#   'contiguous': True},
#  'tsi': {'count': 147456,
#   'missing': 0,
#   'min': 226.93959045410156,
#   'max': 273.1499938964844,
#   'mean': 270.09259033203125,
#   'std': 8.627538681030273,
#   'variance': 74.43441772460938,
#   'contiguous': True},
#  'tsicepdi': {'count': 147456,
#   'missing': 0,
#   'min': 271.0584716796875,
#   'max': 273.1499938964844,
#   'mean': 273.1497802734375,
#   'std': 0.014301297254860401,
#   'variance': 0.0002045271103270352,
#   'contiguous': True},
#  'tslm1': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 328.24383544921875,
#   'mean': 89.86090087890625,
#   'std': 126.64087677001953,
#   'variance': 16037.9111328125,
#   'contiguous': True},
#  'tsurf': {'count': 147456,
#   'missing': 0,
#   'min': 220.69444274902344,
#   'max': 327.6302490234375,
#   'mean': 277.6427917480469,
#   'std': 21.688217163085938,
#   'variance': 470.3787536621094,
#   'contiguous': True},
#  'tsw': {'count': 147456,
#   'missing': 0,
#   'min': 271.3800048828125,
#   'max': 304.1466064453125,
#   'mean': 283.2264099121094,
#   'std': 11.69230842590332,
#   'variance': 136.7100830078125,
#   'contiguous': True},
#  'u10': {'count': 147456,
#   'missing': 0,
#   'min': -22.055299758911133,
#   'max': 24.938800811767578,
#   'mean': 0.0854971781373024,
#   'std': 5.737606525421143,
#   'variance': 32.920127868652344,
#   'contiguous': True},
#  'ustr': {'count': 147456,
#   'missing': 0,
#   'min': -1.884345531463623,
#   'max': 2.6316678524017334,
#   'mean': 0.01946565881371498,
#   'std': 0.1807234138250351,
#   'variance': 0.03266095370054245,
#   'contiguous': True},
#  'ustri': {'count': 147456,
#   'missing': 0,
#   'min': -0.8211102485656738,
#   'max': 1.2881760597229004,
#   'mean': 0.01856043003499508,
#   'std': 0.10154823213815689,
#   'variance': 0.010312043130397797,
#   'contiguous': True},
#  'ustrl': {'count': 147456,
#   'missing': 0,
#   'min': -1.9144219160079956,
#   'max': 2.7582364082336426,
#   'mean': 0.009687887504696846,
#   'std': 0.13530030846595764,
#   'variance': 0.018306171521544456,
#   'contiguous': True},
#  'ustrw': {'count': 147456,
#   'missing': 0,
#   'min': -1.1342741250991821,
#   'max': 1.7458524703979492,
#   'mean': 0.009763520210981369,
#   'std': 0.1209014505147934,
#   'variance': 0.014617159962654114,
#   'contiguous': True},
#  'v10': {'count': 147456,
#   'missing': 0,
#   'min': -22.989906311035156,
#   'max': 23.40787696838379,
#   'mean': -0.07665205746889114,
#   'std': 4.454292297363281,
#   'variance': 19.840721130371094,
#   'contiguous': True},
#  'vdis': {'count': 147456,
#   'missing': 0,
#   'min': 1.0511284926906228e-05,
#   'max': 58.980342864990234,
#   'mean': 1.976112961769104,
#   'std': 3.6376421451568604,
#   'variance': 13.232440948486328,
#   'contiguous': True},
#  'vdisgw': {'count': 147456,
#   'missing': 0,
#   'min': -8.289325307978337e-14,
#   'max': 77.87879943847656,
#   'mean': 0.29950422048568726,
#   'std': 1.5120469331741333,
#   'variance': 2.286285877227783,
#   'contiguous': True},
#  'vstr': {'count': 147456,
#   'missing': 0,
#   'min': -2.1161417961120605,
#   'max': 2.206583023071289,
#   'mean': -0.0052107833325862885,
#   'std': 0.15368328988552094,
#   'variance': 0.023618554696440697,
#   'contiguous': True},
#  'vstri': {'count': 147456,
#   'missing': 0,
#   'min': -1.1748493909835815,
#   'max': 0.8753753304481506,
#   'mean': -0.002141329925507307,
#   'std': 0.07726021856069565,
#   'variance': 0.005969141144305468,
#   'contiguous': True},
#  'vstrl': {'count': 147456,
#   'missing': 0,
#   'min': -2.2710940837860107,
#   'max': 2.265564441680908,
#   'mean': -0.0034447272773832083,
#   'std': 0.1283363401889801,
#   'variance': 0.01647021807730198,
#   'contiguous': True},
#  'vstrw': {'count': 147456,
#   'missing': 0,
#   'min': -1.5014097690582275,
#   'max': 1.1847426891326904,
#   'mean': -0.002028338611125946,
#   'std': 0.089157834649086,
#   'variance': 0.007949119433760643,
#   'contiguous': True},
#  'wimax': {'count': 147456,
#   'missing': 0,
#   'min': 0.05952487885951996,
#   'max': 26.40450096130371,
#   'mean': 6.566003322601318,
#   'std': 3.7922420501708984,
#   'variance': 14.381099700927734,
#   'contiguous': True},
#  'wind10': {'count': 147456,
#   'missing': 0,
#   'min': 0.0450204536318779,
#   'max': 25.79910659790039,
#   'mean': 6.224609375,
#   'std': 3.7194063663482666,
#   'variance': 13.833984375,
#   'contiguous': True},
#  'wl': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 0.0014352246653288603,
#   'mean': 1.862811768660322e-05,
#   'std': 8.878893277142197e-05,
#   'variance': 7.88347520597199e-09,
#   'contiguous': True},
#  'ws': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.1790083646774292,
#   'mean': 0.0805109515786171,
#   'std': 0.17418867349624634,
#   'variance': 0.03034169413149357,
#   'contiguous': True},
#  'wsmx': {'count': 147456,
#   'missing': 0,
#   'min': 0.0,
#   'max': 1.7891627550125122,
#   'mean': 0.1392410397529602,
#   'std': 0.2780666649341583,
#   'variance': 0.07732106745243073,
#   'contiguous': True},
#  'xi': {'count': 6930432,
#   'missing': 0,
#   'min': -2.710505431213761e-20,
#   'max': 0.00033835889189504087,
#   'mean': 1.561211888656544e-06,
#   'std': 9.114038221014198e-06,
#   'variance': 8.306569321270274e-11,
#   'contiguous': True},
#  'xivi': {'count': 147456,
#   'missing': 0,
#   'min': -1.8621305772860495e-21,
#   'max': 0.2802671492099762,
#   'mean': 0.02749221958220005,
#   'std': 0.05285419523715973,
#   'variance': 0.002793565858155489,
#   'contiguous': True},
#  'xl': {'count': 6930432,
#   'missing': 0,
#   'min': -2.710505431213761e-20,
#   'max': 0.0010549292201176286,
#   'mean': 2.3245017928275047e-06,
#   'std': 2.4760121959843673e-05,
#   'variance': 6.130636553969282e-10,
#   'contiguous': True},
#  'xlvi': {'count': 147456,
#   'missing': 0,
#   'min': -1.2441534534169333e-21,
#   'max': 1.4544718265533447,
#   'mean': 0.037350911647081375,
#   'std': 0.08342093974351883,
#   'variance': 0.006959053222090006,
#   'contiguous': True}}

# %% [markdown]
# ### Report

# %%
report = ds.report()
report.to_file('report.json')
# Out:
# Wrote file report.json, 79715 bytes.
